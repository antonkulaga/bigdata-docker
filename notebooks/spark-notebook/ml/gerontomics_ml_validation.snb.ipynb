// %%
import org.bdgenomics.adam.rdd.ADAMContext._
import comp.bio.aging.playground.extensions._
import org.apache.spark.sql._
import org.apache.spark.sql.SparkSession
import frameless.functions.aggregate
import frameless.TypedDataset
import frameless.syntax._

implicit val session = SparkSession
  .builder()
  .appName("Spark SQL basic example")
  .config("spark.some.config.option", "some-value")
  .getOrCreate()
// Out:
// import org.bdgenomics.adam.rdd.ADAMContext._
// import comp.bio.aging.playground.extensions._
// import org.apache.spark.sql._
// import org.apache.spark.sql.SparkSession
// import frameless.functions.aggregate
// import frameless.TypedDataset
// import frameless.syntax._
// session: org.apache.spark.sql.SparkSession = org.apache.spark.sql.SparkSession@792ff40d

// %%
val base = "hdfs://namenode/pipelines"
val ml = s"${base}/ml"
val genAgePath = s"${ml}/genage_LAGs_list.xlsx"
val vladFilePath = s"${ml}/ML validation (11.12.2017).xlsx"
// Out:
// base: String = hdfs://namenode/pipelines
// ml: String = hdfs://namenode/pipelines/ml
// genAgePath: String = hdfs://namenode/pipelines/ml/genage_LAGs_list.xlsx
// vladFilePath: String = hdfs://namenode/pipelines/ml/ML validation (11.12.2017).xlsx

// %%
def openSpreadsheet(location: String, sheet: String, emptyAsNulls: Boolean = false, colorColumns: Boolean = false)
                   (implicit sessions: SparkSession): DataFrame = {
  sessions.read
    .format("com.crealytics.spark.excel")
    .option("sheetName", sheet) // Required
    .option("useHeader", "true") // Required
    .option("treatEmptyValuesAsNulls", emptyAsNulls.toString) // Optional, default: true
    .option("inferSchema", "true") // Optional, default: false
    .option("addColorColumns", colorColumns.toString) // Optional, default: false
    .load(location)
}
// Out:
// openSpreadsheet: (location: String, sheet: String, emptyAsNulls: Boolean, colorColumns: Boolean)(implicit sessions: org.apache.spark.sql.SparkSession)org.apache.spark.sql.DataFrame

// %%
val genAgeHuman = openSpreadsheet(genAgePath, "genage_human")
  .withColumnRenamed("entrez gene id", "entrez").cache
genAgeHuman
// Out:
// genAgeHuman: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [GenAge ID: double, symbol: string ... 14 more fields]
// res4: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [GenAge ID: double, symbol: string ... 14 more fields]
// <div class="df-canvas">
//       <script data-this="{&quot;dataId&quot;:&quot;anon9d36bc97c7583f9432acd225ec788a61&quot;,&quot;partitionIndexId&quot;:&quot;anon5d247fd6efc6b18faac876f394d988a5&quot;,&quot;numPartitions&quot;:13,&quot;dfSchema&quot;:{&quot;type&quot;:&quot;struct&quot;,&quot;fields&quot;:[{&quot;name&quot;:&quot;GenAge ID&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;symbol&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;aliases&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;name&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;entrez&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;uniprot&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;why&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;band&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;location start&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;location end&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;orientation&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;acc promoter&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;acc orf&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;acc cds&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;references&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;orthologs&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}}]}}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/dataframe','../javascripts/notebook/consoleDir'],
//       function(dataframe, extension) {
//         dataframe.call(data, this, extension);
//       }
//     );/*]]>*/</script>
//       <link rel="stylesheet" href="/assets/stylesheets/ipython/css/dataframe.css" type="text/css"/>
//     </div>

// %%
val genAgeModel = openSpreadsheet(genAgePath, "genage_models").withColumnRenamed("entrez gene id", "entrez").cache
genAgeModel

// %%
import frameless.TypedDataset
import frameless.syntax._
import session.implicits._

import org.apache.spark.sql.functions._

val toDouble = udf[Double, String](s => if(s!=null) s.replace(",","").toDouble else 0.0)

val vladGenes = Seq("WRN", "LMNA", "FOXO1", "APOE", "Gdf15", "GHR", "Ghrh", "IGF1", "Pou1f1", "age-1", "daf-2", "Tor", "osm-5", "unc-13")
def openVladSheet(sheet: String) = {
  val df = openSpreadsheet(vladFilePath, sheet)
  df
    //.withColumn("Entrez", toInt(df("Entrez")))
    .withColumn("Score", toDouble(df("Score")))
    //.withColumn("TaxID", toInt(df("TaxID")))
    .withColumnRenamed("Effect on CS (CellAge)", "CellAge")
    //.withColumnRenamed("C6", "GenAge")
    .withColumn("predicted_for", lit(sheet))
    .select("predicted_for", "ORD", "Entrez",   "TaxID", "Score", "Symbol", "CellAge", "Comment")  
}
val predictions = vladGenes.map(g=>openVladSheet(g)).reduce((a,b)=> a.union(b)).cache
predictions
// Out:
// import frameless.TypedDataset
// import frameless.syntax._
// import session.implicits._
// import org.apache.spark.sql.functions._
// toDouble: org.apache.spark.sql.expressions.UserDefinedFunction = UserDefinedFunction(<function1>,DoubleType,Some(List(StringType)))
// vladGenes: Seq[String] = List(WRN, LMNA, FOXO1, APOE, Gdf15, GHR, Ghrh, IGF1, Pou1f1, age-1, daf-2, Tor, osm-5, unc-13)
// openVladSheet: (sheet: String)org.apache.spark.sql.DataFrame
// predictions: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [predicted_for: string, ORD: string ... 6 more fields]
// res8: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [predicted_for: string, ORD: string ... 6 more fields]

// %%
predictions.show(100)
// Out:
// +-------------+---+------------+-------+---------+---------+--------------------+--------------------+
// |predicted_for|ORD|      Entrez|  TaxID|    Score|   Symbol|             CellAge|             Comment|
// +-------------+---+------------+-------+---------+---------+--------------------+--------------------+
// |          WRN| 0.|      7486.0| 9606.0|1000000.0|      WRN|Inhibits;WRN expr...|Werner progeroid ...|
// |          WRN| 1.|     55183.0| 9606.0| 0.883706|     RIF1|                null|                null|
// |          WRN| 2.|      5981.0| 9606.0| 0.877486|     RFC1|                null|                null|
// |          WRN| 3.|     56916.0| 9606.0| 0.856532| SMARCAD1|                null|                null|
// |          WRN| 4.|    257218.0| 9606.0| 0.856138|    SHPRH|                null|                null|
// |          WRN| 5.|     84146.0| 9606.0| 0.856087|   ZNF644|                null|                null|
// |          WRN| 6.|       545.0| 9606.0| 0.853317|      ATR|                null|                null|
// |          WRN| 7.|     57187.0| 9606.0| 0.849505|    THOC2|                null|                null|
// |          WRN| 8.|      9126.0| 9606.0| 0.849017|     SMC3|                null|                null|
// |          WRN| 9.|     55749.0| 9606.0| 0.848623|    CCAR1|                null|                null|
// |          WRN|10.|      4361.0| 9606.0| 0.846844|    MRE11|                null|                null|
// |          WRN|11.|     23063.0| 9606.0| 0.843678|     WAPL|                null|                null|
// |          WRN|12.|     85459.0| 9606.0| 0.840637|   CEP295|                null|                null|
// |          WRN|13.|      9648.0| 9606.0| 0.839431|     GCC2|                null|                null|
// |          WRN|14.|     23350.0| 9606.0| 0.838958|   U2SURP|                null|                null|
// |          WRN|15.|     10111.0| 9606.0| 0.837968|    RAD50|                null|                null|
// |          WRN|16.|     64062.0| 9606.0| 0.837818|    RBM26|                null|                null|
// |          WRN|17.|     55023.0| 9606.0| 0.836238|     PHIP|                null|                null|
// |          WRN|18.|      7155.0| 9606.0| 0.835528|    TOP2B|                null|                null|
// |          WRN|19.|     55814.0| 9606.0| 0.834959|     BDP1|                null|                null|
// |          WRN|20.|     51426.0| 9606.0| 0.834708|     POLK|                null|                null|
// |          WRN|21.|     80184.0| 9606.0|  0.83347|   CEP290|                null|                null|
// |          WRN|22.|     57703.0| 9606.0| 0.833015|    CWC22|                null|                null|
// |          WRN|23.|     84128.0| 9606.0| 0.832832|    WDR75|                null|                null|
// |          WRN|24.|      9321.0| 9606.0| 0.832241|   TRIP11|                null|                null|
// |          WRN|25.|      7175.0| 9606.0| 0.830185|      TPR|Inhibits;Depletio...|                null|
// |          WRN|26.|     23047.0| 9606.0| 0.828827|    PDS5B|                null|                null|
// |          WRN|27.|     23244.0| 9606.0| 0.826825|    PDS5A|                null|                null|
// |          WRN|28.|     51773.0| 9606.0| 0.826658|     RSF1|                null|                null|
// |          WRN|29.|      4976.0| 9606.0| 0.826633|     OPA1|                null|                null|
// |          WRN|30.|     10198.0| 9606.0| 0.825413| MPHOSPH9|                null|                null|
// |         LMNA| 0.|      4000.0|   9606|1000000.0|     LMNA|                null|Lamin A/C; Hutchi...|
// |         LMNA| 1.|1.00506002E8|      -| 0.881561|        -|                null|                null|
// |         LMNA| 2.|     23476.0|   9606| 0.878955|     BRD4|                null|                null|
// |         LMNA| 3.|     80127.0|   9606| 0.875015|    BBOF1|                null|                null|
// |         LMNA| 4.|     10495.0|   9606| 0.872137|    ENOX2|                null|                null|
// |         LMNA| 5.|      5581.0|   9606| 0.866431|    PRKCE|                null|                null|
// |         LMNA| 6.|      8468.0|   9606| 0.863086|    FKBP6|                null|                null|
// |         LMNA| 7.|     79685.0|   9606|  0.86247|   SAP30L|                null|                null|
// |         LMNA| 8.|    112939.0|   9606| 0.860284|    NACC1|                null|                null|
// |         LMNA| 9.|     79778.0|   9606| 0.858576|  MICALL2|                null|                null|
// |         LMNA|10.|    116985.0|   9606| 0.857972|    ARAP1|                null|                null|
// |         LMNA|11.|     26993.0|   9606| 0.857957|   AKAP8L|                null|                null|
// |         LMNA|12.|    283335.0|   9606| 0.857629|LOC283335|                null|                null|
// |         LMNA|13.|      7343.0|   9606| 0.857628|     UBTF|                null|                null|
// |         LMNA|14.|      8498.0|   9606| 0.857449|   RANBP3|                null|                null|
// |         LMNA|15.|     11338.0|   9606| 0.857047|    U2AF2|                null|                null|
// |         LMNA|16.|    145497.0|   9606| 0.854391|  LRRC74A|                null|                null|
// |         LMNA|17.|      8934.0|   9606| 0.853256|    RAB29|                null|                null|
// |         LMNA|18.|     83855.0|   9606| 0.853022|    KLF16|                null|                null|
// |         LMNA|19.|      9260.0|   9606| 0.851996|   PDLIM7|                null|                null|
// |         LMNA|20.|     81603.0|   9606| 0.851944|    TRIM8|                null|                null|
// |         LMNA|21.|     10454.0|   9606| 0.851082|     TAB1|                null|                null|
// |         LMNA|22.|    400027.0|   9606| 0.850726|LINC00938|                null|                null|
// |         LMNA|23.|      2902.0|   9606| 0.849483|    GRIN1|                null|                null|
// |         LMNA|24.|     11054.0|   9606| 0.848191|     OGFR|                null|                null|
// |         LMNA|25.|     29775.0|   9606| 0.847572|   CARD10|                null|                null|
// |         LMNA|26.|1.00505574E8|      -| 0.847037|        -|                null|                null|
// |         LMNA|27.|    150094.0|   9606| 0.846697|     SIK1|Promotes;A librar...|                null|
// |         LMNA|28.|     26121.0|   9606| 0.846218|   PRPF31|                null|                null|
// |         LMNA|29.|      4054.0|   9606| 0.846064|    LTBP3|                null|                null|
// |         LMNA|30.|    375790.0|   9606| 0.844912|     AGRN|                null|                null|
// |        FOXO1| 0.|      2308.0| 9606.0|1000000.0|    FOXO1|                null|homolog of DAF16....|
// |        FOXO1| 1.|1.00132074E8| 9606.0|  0.83739|    FOXO6|                null|makes sense - ent...|
// |        FOXO1| 2.|      4303.0| 9606.0| 0.796263|    FOXO4|                null|makes sense - ent...|
// |        FOXO1| 3.|      2310.0| 9606.0| 0.771318|   FOXO3B|                null|makes sense - ent...|
// |        FOXO1| 4.|      2309.0| 9606.0| 0.749159|    FOXO3|Inhibits;RNA inte...|makes sense - ent...|
// |        FOXO1| 5.|      7528.0| 9606.0| 0.721453|      YY1|                null|                null|
// |        FOXO1| 6.|      1385.0| 9606.0| 0.719386|    CREB1|                null|type 2 diabetes, ...|
// |        FOXO1| 7.|      3170.0| 9606.0| 0.713863|    FOXA2|                null|makes sense - ent...|
// |        FOXO1| 8.|      9643.0| 9606.0| 0.708576|  MORF4L2|                null|                null|
// |        FOXO1| 9.|      7329.0| 9606.0|  0.70632|    UBE2I|                null|                null|
// |        FOXO1|10.|      8456.0| 9606.0| 0.704817|    FOXN1|                null|makes sense - ent...|
// |        FOXO1|11.|      8431.0| 9606.0| 0.704131|    NR0B2|                null|                null|
// |        FOXO1|12.|    139628.0| 9606.0| 0.696095|    FOXR2|                null|makes sense - ent...|
// |        FOXO1|13.|      6304.0| 9606.0| 0.694246|    SATB1|                null|                null|
// |        FOXO1|14.|      6256.0| 9606.0| 0.694202|     RXRA|                null|                null|
// |        FOXO1|15.|     54556.0| 9606.0| 0.693644|     ING3|                null|                null|
// |        FOXO1|16.|      3066.0| 9606.0| 0.692392|    HDAC2|                null|HDAC2: deacetylat...|
// |        FOXO1|17.|     80854.0| 9606.0| 0.690728|    SETD7|                null|                null|
// |        FOXO1|18.|       896.0| 9606.0|  0.68858|    CCND3|                null|                null|
// |        FOXO1|19.|      5468.0| 9606.0| 0.687095|    PPARG|                null|Regulates Klotho ...|
// |        FOXO1|20.|      6258.0| 9606.0| 0.686368|     RXRG|                null|                null|
// |        FOXO1|21.|     10541.0| 9606.0|  0.68452|   ANP32B|                null|                null|
// |        FOXO1|22.|      2307.0| 9606.0| 0.680253|    FOXS1|                null|makes sense - ent...|
// |        FOXO1|23.|1.00288092E8|    NaN| 0.679559|        -|                null|                null|
// |        FOXO1|24.|      4773.0| 9606.0| 0.679054|   NFATC2|                null|                null|
// |        FOXO1|25.|      2063.0| 9606.0| 0.678987|    NR2F6|                null|                null|
// |        FOXO1|26.|     23411.0| 9606.0|  0.67889|    SIRT1|Inhibits;Overexpr...|Many relations to...|
// |        FOXO1|27.|      8648.0| 9606.0| 0.678294|    NCOA1|                null|                null|
// |        FOXO1|28.|     10524.0| 9606.0| 0.678114|     KAT5|                null|                null|
// |        FOXO1|29.|      6597.0| 9606.0| 0.676774|  SMARCA4|Inhibits;Knockdow...|cellular senescen...|
// |        FOXO1|30.|     10014.0| 9606.0| 0.676607|    HDAC5|                null|probably another ...|
// |         APOE| 0.|       348.0| 9606.0|1000000.0|     APOE|                null|APOE polymorphism...|
// |         APOE| 1.|    140545.0| 9606.0| 0.746208|    RNF32|                null|                null|
// |         APOE| 2.|      2639.0| 9606.0| 0.738191|     GCDH|                null|                null|
// |         APOE| 3.|         2.0| 9606.0|   0.7306|      A2M|                null|                null|
// |         APOE| 4.|      5664.0| 9606.0| 0.718948|    PSEN2|                null|                null|
// |         APOE| 5.|     11732.0|10090.0| 0.717478|      Ank|                null|                null|
// |         APOE| 6.|      9361.0| 9606.0| 0.701786|    LONP1|                null|                null|
// +-------------+---+------------+-------+---------+---------+--------------------+--------------------+
// only showing top 100 rows

// %%
genAgeModel
// Out:
// res12: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [GenAge ID: double, symbol: string ... 6 more fields]
// <div class="df-canvas">
//       <script data-this="{&quot;dataId&quot;:&quot;anon086816facaa3e28e628737447b45f320&quot;,&quot;partitionIndexId&quot;:&quot;anonbdffe9879d8c10148da5b3df1c3c6739&quot;,&quot;numPartitions&quot;:87,&quot;dfSchema&quot;:{&quot;type&quot;:&quot;struct&quot;,&quot;fields&quot;:[{&quot;name&quot;:&quot;GenAge ID&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;symbol&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;name&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;organism&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;entrez&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;avg lifespan change (max obsv)&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;lifespan effect&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;longevity influence&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}}]}}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/dataframe','../javascripts/notebook/consoleDir'],
//       function(dataframe, extension) {
//         dataframe.call(data, this, extension);
//       }
//     );/*]]>*/</script>
//       <link rel="stylesheet" href="/assets/stylesheets/ipython/css/dataframe.css" type="text/css"/>
//     </div>

// %%
val modeled = predictions
  .join(genAgeModel, genAgeModel("entrez") === predictions("Entrez"))
  .drop(genAgeModel("entrez"))  
  .drop(genAgeModel("symbol"))  
  .cache
modeled
// Out:
// modeled: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [predicted_for: string, ORD: string ... 12 more fields]
// res14: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [predicted_for: string, ORD: string ... 12 more fields]
// <div class="df-canvas">
//       <script data-this="{&quot;dataId&quot;:&quot;anonc3cd0ea09adc8fd734a2010dae106406&quot;,&quot;partitionIndexId&quot;:&quot;anond9b2ac47edf236eebd44c3e9c98e4efa&quot;,&quot;numPartitions&quot;:1,&quot;dfSchema&quot;:{&quot;type&quot;:&quot;struct&quot;,&quot;fields&quot;:[{&quot;name&quot;:&quot;predicted_for&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:false,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;ORD&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Entrez&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;TaxID&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Score&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Symbol&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;CellAge&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Comment&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;GenAge ID&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;name&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;organism&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;avg lifespan change (max obsv)&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;lifespan effect&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;longevity influence&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}}]}}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/dataframe','../javascripts/notebook/consoleDir'],
//       function(dataframe, extension) {
//         dataframe.call(data, this, extension);
//       }
//     );/*]]>*/</script>
//       <link rel="stylesheet" href="/assets/stylesheets/ipython/css/dataframe.css" type="text/css"/>
//     </div>

// %%
val humaned  = predictions
  .join(genAgeHuman, predictions("Entrez") === genAgeHuman("entrez"))
  .drop(genAgeHuman("entrez"))  
  .drop(genAgeHuman("symbol"))  
  .cache
humaned
// Out:
// humaned: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [predicted_for: string, ORD: string ... 20 more fields]
// res16: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [predicted_for: string, ORD: string ... 20 more fields]
// <div class="df-canvas">
//       <script data-this="{&quot;dataId&quot;:&quot;anon316369b9e1e51bb73af8ea1fb3ada8ed&quot;,&quot;partitionIndexId&quot;:&quot;anonae8bbd8aa02e6f80ec4ec89fd591aabf&quot;,&quot;numPartitions&quot;:2,&quot;dfSchema&quot;:{&quot;type&quot;:&quot;struct&quot;,&quot;fields&quot;:[{&quot;name&quot;:&quot;predicted_for&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:false,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;ORD&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Entrez&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;TaxID&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Score&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Symbol&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;CellAge&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Comment&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;GenAge ID&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;aliases&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;name&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;uniprot&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;why&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;band&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;location start&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;location end&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;orientation&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;acc promoter&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;acc orf&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;acc cds&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;references&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;orthologs&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}}]}}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/dataframe','../javascripts/notebook/consoleDir'],
//       function(dataframe, extension) {
//         dataframe.call(data, this, extension);
//       }
//     );/*]]>*/</script>
//       <link rel="stylesheet" href="/assets/stylesheets/ipython/css/dataframe.css" type="text/css"/>
//     </div>

// %%
val predictedIds = 
    modeled.select("Entrez").map(_.getDouble(0)).collect() ++ humaned.select("Entrez").map(_.getDouble(0)).collect()
val notInGenAge = predictions.filter( r=> !predictedIds.contains(r.getAs[Double]("Entrez")))
notInGenAge
// Out:
// predictedIds: Array[Double] = Array(23886.0, 14600.0, 14601.0, 16000.0, 18736.0, 174762.0, 175410.0, 180982.0, 178104.0, 174462.0, 176065.0, 175559.0, 181055.0, 178113.0, 172167.0, 177770.0, 173960.0, 180585.0, 189055.0, 180401.0, 179666.0, 172497.0, 179412.0, 7486.0, 545.0, 7155.0, 4000.0, 2308.0, 4303.0, 2309.0, 1385.0, 7329.0, 3066.0, 5468.0, 23411.0, 348.0, 2.0, 5663.0, 6648.0, 2690.0, 6464.0, 5295.0, 3717.0, 5781.0, 3643.0, 3667.0, 5747.0, 25.0, 5159.0, 3480.0, 8835.0, 2692.0, 3479.0, 3481.0, 3486.0, 5054.0, 5449.0, 5468.0, 10891.0, 5469.0, 5465.0, 3725.0, 1051.0)
// notInGenAge: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [predicted_for: string, ORD: string ... 6 more fields]
// res18: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [predicted_for: string, ORD: str...
// <div class="df-canvas">
//       <script data-this="{&quot;dataId&quot;:&quot;anon3edba1f359a33d98ea3a6ea7258594ea&quot;,&quot;partitionIndexId&quot;:&quot;anoncc2731e936140c972d0781f0e3bc2633&quot;,&quot;numPartitions&quot;:15,&quot;dfSchema&quot;:{&quot;type&quot;:&quot;struct&quot;,&quot;fields&quot;:[{&quot;name&quot;:&quot;predicted_for&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:false,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;ORD&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Entrez&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;TaxID&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Score&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Symbol&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;CellAge&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;Comment&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}}]}}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/dataframe','../javascripts/notebook/consoleDir'],
//       function(dataframe, extension) {
//         dataframe.call(data, this, extension);
//       }
//     );/*]]>*/</script>
//       <link rel="stylesheet" href="/assets/stylesheets/ipython/css/dataframe.css" type="text/css"/>
//     </div>

// %%
modeled.coalesce(1).write.option("sep", "\t").csv(ml + "/predictions_models.tsv")
humaned.coalesce(1).write.option("sep", "\t").csv(ml + "/predictions_human.tsv")
notInGenAge.coalesce(1).write.option("sep", "\t").csv(ml + "/predictions_notfound.tsv")

// %%
(predictions.count, modeled.count, humaned.count, notInGenAge.count)
// Out:
// res140: (Long, Long, Long, Long) = (437,23,40,374)
// (437,23,40,374)
